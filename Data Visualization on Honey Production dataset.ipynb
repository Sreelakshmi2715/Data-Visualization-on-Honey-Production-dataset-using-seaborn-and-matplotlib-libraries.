# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries

# %% [markdown]
# 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\FCI-1626\Downloads\honeyproduction.csv")

# %%
data_copy=data.copy()

# %% [markdown]
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
data.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
data.describe().T
# Out:
#              count          mean           std        min          25%  \
# numcol       626.0  6.028435e+04  9.107709e+04    2000.00    9000.0000
# yieldpercol  626.0  6.200958e+01  1.945875e+01      19.00      48.0000
# totalprod    626.0  4.169086e+06  6.883847e+06   84000.00  475000.0000
# stocks       626.0  1.318859e+06  2.272964e+06    8000.00  143000.0000
# priceperlb   626.0  1.409569e+00  6.385989e-01       0.49       0.9325
# prodvalue    626.0  4.715741e+06  7.976110e+06  162000.00  759250.0000
# year         626.0  2.004864e+03  4.317306e+00    1998.00    2001.0000
#
#                     50%         75%          max
# numcol         26000.00    63750.00    510000.00
# yieldpercol       60.00       74.00       136.00
# totalprod    1533000.00  4175250.00  46410000.00
# stocks        439500.00  1489500.00  13800000.00
# priceperlb         1.36        1.68         4.15
# prodvalue    1841500.00  4703250.00  69615000.00
# year            2005.00     2009.00      2012.00

# %%
data.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
year_distribution=data['year'].value_counts(normalize=True)*100

# %%
plt.pie(year_distribution,autopct='%.1f%%',radius=1.2)
plt.show()

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.distplot(data["priceperlb"],kde=True)
plt.show()
# Out:
# C:\Users\FCI-1626\AppData\Local\Temp\ipykernel_6736\4099817272.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["priceperlb"],kde=True)

# %%
#the data is postively skewed

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(x=data['numcol'],y=data['prodvalue'])
plt.show()

# %%
#the two columns Number of colonies and product values is positively correlated.
#that is when the number of honey producing colonies increases the product value also increases

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
data.boxplot(column='prodvalue',by='year')
plt.show()

# %%
sns.boxplot(x=data['year'],y=data['prodvalue'])
# Out:
# <Axes: xlabel='year', ylabel='prodvalue'>

# %%
#on the year 1998 the median value is colser to the left of the box and the whisker is shorter
#on the left, hence we can say that the data is positively skewed.That is majority of product
#values are lower with a few higher values as outliers.

#over the years there is slight increase in the product value and the heighest value got on the
#year 2010.

#on the year 2012 the data is slightly positively skewed and drastic change in the oulier values,that is they got higher.
#overall we can say that the product increased over years from 1998 to 2012

# %% [markdown]
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data[['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']])
plt.show()
# Out:
# C:\Users\FCI-1626\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#the columns numcol and totalprod, numcol and prodvalue, totalprod and prodvalue are positively correlated.

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences.

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
plt.show()

# %%
# the columns numcol and total production is highly positively correlated
# the total production and year is highly negatively correlated,that over the years total production decrease
